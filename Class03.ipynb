# %%
A = "sayem.com"
byte = (A, 'utf-8')
print(byte)
num = 3
ans = bytes(num)
print(ans)
# Out:
# ('sayem.com', 'utf-8')
# b'\x00\x00\x00'

# %%
tpl = (2,5,7,21,3,11)
print(tpl[3])
print(tpl)
# Out:
# 21
# (2, 5, 7, 21, 3, 11)

# %%
print(bytes())
# Out:
# b''

# %%
tple = (3, 12, 23, 14, 15)
print(str(bytes(tple)))
# Out:
# b'\x03\x0c\x17\x0e\x0f'

# %%
A = "Anwarul"
B = " Azim"
C = A +""+ B
D = A + B
print(C)
print(D)
print(A + B)
print(f"The name is {C}")
# Out:
# Anwarul Azim
# Anwarul Azim
# Anwarul Azim
# The name is Anwarul Azim

# %%
Number1 = float(input("Enter 1st number: "))
Number2 = float(input("Enter 2nd number: "))
print("Summation:",Number1 + Number2)
print("Subdivition:",Number1 - Number2)
print("Multiplication:", Number1 * Number2)
print("Division", Number1 / Number2)
# Out:
# Enter 1st number: 100
# Enter 2nd number: 20
# Summation: 120.0
# Subdivition: 80.0
# Multiplication: 2000.0
# Division 5.0
